# %% [markdown]
# Sopa de letras
# Instrucciones:
#
# 1.   Busca todas las palabras ocultas dentro de la sopa de letras
# 2.   Completa todas las palabras para finalizar el juego y ver tu puntuacion
# 3.   Verifica las palabras tachadas en la lista para asegurarte de cuales ya encontraste
# 4.   El juego va a finalizar cuando hayas encontrado las 5 palabras ocultas
# 5.   Comparte tu resultado al finalizar para competir con otros jugadores

# %%
print("✨✨✨✨✨✨✨✨✨✨✨✨✨✨✨")
print("✨   Bienvenido al juego Cazapalabras   ✨")
print("✨✨✨✨✨✨✨✨✨✨✨✨✨✨✨")
# Out:
# ✨✨✨✨✨✨✨✨✨✨✨✨✨✨✨
# ✨   Bienvenido al juego Cazapalabras   ✨
# ✨✨✨✨✨✨✨✨✨✨✨✨✨✨✨

# %%
print(" t n g i t h u b n o y a \n s a m n j p y a e b c g \n a m p h y t h o n m c r \n n a n d s t l k m h b v \n p y c o l a b o n b t w \n q w e r s e l s e p a s \n c o l m a t j k l a s d \n f g a l g o r i t m o n \n o n z c r u d x e m v j \n o m n t a b u t f h c o \n t p a n a n d s t s t v \n p r i o m e n g w z y a ")
Palabra=0
while(Palabra<5):
  Var1=input("Dame una palabra")
  if(Var1=="github"):
      Palabra=Palabra+1
  elif(Var1=="phython"):
      Palabra=Palabra+1
  elif(Var1=="colab"):
      Palabra=Palabra+1
  elif(Var1=="else"):
      Palabra=Palabra+1
  elif(Var1=="algoritmo"):
      Palabra=Palabra+1
print("ya ganaste")

# %% [markdown]
# Integrantes:
#
# Geraldine Morales Peña
#
# Ximena Joseline Benitez Rodriguez
#
# Maria del Rosario Lopez Jimenez
#
# Erick Merida Peregrina
#
# Manuel Eduardo Sánchez Cano
